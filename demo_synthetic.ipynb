# %% [markdown]
# # Demo: Fractal Dimension of Tracks
#
# This notebook simply runs the command-line tool to generate synthetic examples and plots.

# %%
import sys, subprocess, os, pathlib
tool = pathlib.Path('boxcount_tracks.py').resolve()
out = pathlib.Path('out_demo').resolve()
out.mkdir(exist_ok=True)
subprocess.run([sys.executable, str(tool), '--demo', '--out', str(out)], check=True)
print('Wrote outputs to', out)
